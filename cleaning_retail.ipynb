# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fuzzywuzzy import process
# Out:
# c:\Users\aerif\AppData\Local\Programs\Python\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_excel('Dataset.xlsx')
df.head()
# Out:
#                id customer_id order_date   sku_id    price  qty_ordered  \
# 0  ODR9939707760w    C713589L 2021-11-19  P858068    26100          200
# 1  ODR7448356649d    C551551L 2021-11-19  P886455  1971942            5
# 2  ODR4011281866z    C685596L 2021-11-25  P678648  7482000            1
# 3  ODR3378927994s    C830683L 2021-11-22  P540013  3593680            1
# 4  ODR4904430099k    C191766L 2021-11-21  P491032  4413220            1
#
#    before_discount  discount_amount  after_discount  is_gross  is_valid  \
# 0          5220000          2610000         2610000         1         1
# 1          9859710          2464927         7394782         1         0
# 2          7482000          2065344         5416655         1         0
# 3          3593680          1455440         2138239         1         1
# 4          4413220          1059172         3354047         1         1
#
#    is_net  payment_id payment_method  \
# 0       0           5     jazzwallet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5860 entries, 0 to 5883
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5860 non-null   object
#  1   customer_id      5860 non-null   object
#  2   order_date       5860 non-null   datetime64[ns]
#  3   sku_id           5860 non-null   object
#  4   price            5860 non-null   int64
#  5   qty_ordered      5860 non-null   int64
#  6   before_discount  5860 non-null   int64
#  7   discount_amount  5860 non-null   int64
#  8   after_discount   5860 non-null   int64
#  9   is_gross         5860 non-null   int64
#  10  is_valid         5860 non-null   int64
#  11  is_net           5860 non-null   int64
#  12  payment_id       5860 non-null   int64
#  13  payment_method   5860 non-null   object
#  14  sku_name         5860 non-null   object
#  15  base_price       5860 non-null   int64
#  16  cogs             5860 non-null   int64
# ...

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df_cleaned = df.duplicated().sum()
#df = df.drop_duplicates(subset=[1], keep=False)

# %%
df_cleaned = df[df["price"] > 0]  
df_cleaned = df_cleaned[df_cleaned["qty_ordered"] > 0]
df_cleaned = df_cleaned.drop_duplicates(subset=["id"])  
df_cleaned["payment_method"] = df_cleaned["payment_method"].str.lower().str.strip() 
df_cleaned["sku_name"] = df_cleaned["sku_name"].str.lower().str.strip()
